# %%
import numpy as np

A = np.array([[4, -2],[1, 1]])

eigvals, eigvec = np.linalg.eig(A)

print("EigenValues: ",eigvals)
print("EigenVectors: \n",eigvec)
# Out:
# EigenValues:  [3. 2.]
# EigenVectors:
#  [[0.89442719 0.70710678]
#  [0.4472136  0.70710678]]
